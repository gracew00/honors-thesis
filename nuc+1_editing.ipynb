# %%
import pandas as pd

# %%
file_path = "/home/ubuntu/honors_research/peak_align/TSS_all_adj+1Nuc.bed"
df = pd.read_csv(file_path, sep="\t")
df
# Out:
#          TSS  Unnamed: 1  Unnamed: 2                 Unnamed: 3  CoPRO read2  \
# 0       chr1    21782419    21782419     chr1_21782419_21782419            5
# 1      chr16    68085718    68085718    chr16_68085718_68085718           16
# 2       chr1   148634329   148634329   chr1_148634329_148634329            5
# 3       chr1   156747365   156747365   chr1_156747365_156747365            7
# 4       chr1   172449989   172449989   chr1_172449989_172449989           10
# ...      ...         ...         ...                        ...          ...
# 51311  chr18    57435408    57435408    chr18_57435408_57435408          126
# 51312  chr19    37251877    37251877    chr19_37251877_37251877            5
# 51313   chr8     1701428     1701428       chr8_1701428_1701428            7
# 51314  chr13   108215535   108215535  chr13_108215535_108215535            9
# 51315  chr16     1153106     1153106      chr16_1153106_1153106           39
#
#       Unnamed: 5  Distance to closest nuc  \
# 0              +                      -19
# 1              +                       -8
# 2              -                       40
# 3              +                       43
# 4              -                       40
# ...          ...                      ...
# 51311          +                      967
# 51312          +                      988
# 51313          -                     1000
# 51314          -                       21
# 51315          +                     1160
#
#                          TSS informaion, phase to +1 Nuc        NFR  \
# 0      -3_AA_-2_-1_TA_0_1_CT_2_c_main_NDR_First_Diver...   21782090
# 1      -3_CT_-2_-1_CG_0_1_AC_2_c_main_NDR_First_Diver...   68085547
# 2      -3_AT_-2_-1_TA_0_1_CT_2_c_main_NFR_First_Singl...  148634288
# 3      -3_AC_-2_-1_CA_0_1_CA_2_c_main_NFR_First_Diver...  156747072
# 4      -3_TC_-2_-1_CA_0_1_CT_2_c_main_NFR_First_Refer...  172449948
# ...                                                  ...        ...
# 51311  -3_AA_-2_-1_CA_0_1_GA_2_c_main_NFR_First_Refer...   57435098
# 51312  -3_CC_-2_-1_CA_0_1_CG_2_c_main_NFR_First_Singl...   37251700
# 51313  -3_CG_-2_-1_AG_0_1_GG_2_c_main_NFR_First_Diver...    1700427
# 51314  -3_GG_-2_-1_CA_0_1_TC_2_c_main_NDR_First_Diver...  108214517
# 51315  -3_CT_-2_-1_CA_0_1_GC_2_c_main_NFR_First_Refer...    1152850
#
#        Unnamed: 9  ...                Unnamed: 19  PIC occupancy Unnamed: 21  \
# 0        21782447  ...   chr1_21782389_21782397_+         -74.59           +
# 1        68085745  ...    chr16_68085691_68085691         -45.53           +
# 2       148634456  ...   chr1_148634356_148634356         -44.55           -
# 3       156747409  ...   chr1_156747338_156747338         -30.61           +
# 4       172450257  ...   chr1_172450016_172450016         -52.57           -
# ...           ...  ...                        ...            ...         ...
# 51311    57436376  ...    chr18_57435381_57435381         -31.11           +
# 51312    37252866  ...    chr19_37251850_37251850         -37.95           +
# 51313     1701607  ...       chr8_1701455_1701455         -31.45           -
# 51314   108215789  ...  chr13_108215562_108215562         -33.84           -
# 51315     1154267  ...      chr16_1153079_1153079         -55.73           +
#
#       Adjusted +1 Nucleosome  Unnamed: 23  Unnamed: 24  \
# 0                       chr1     21782449     21782449
# 1                      chr16     68085748     68085748
# 2                       chr1    148634289    148634289
# 3                       chr1    156747405    156747405
# 4                       chr1    172449949    172449949
# ...                      ...          ...          ...
# 51311                  chr18     57436376     57436376
# 51312                  chr19     37252866     37252866
# 51313                   chr8      1700427      1700427
# 51314                  chr13    108214517    108214517
# 51315                  chr16      1154267      1154267
#
#                      Unnamed: 25  Distance to TSS  Unnamed: 27 phase socre
# 0         chr1_21782449_21782449               30            +    0.280488
# 1        chr16_68085748_68085748               30            +    0.052631
# 2       chr1_148634289_148634289               40            -    0.033708
# 3       chr1_156747405_156747405               40            +    0.135594
# 4       chr1_172449949_172449949               40            -    0.252252
# ...                          ...              ...          ...         ...
# 51311    chr18_57436376_57436376              968            +    0.000000
# 51312    chr19_37252866_37252866              989            +    0.000000
# 51313       chr8_1700427_1700427             1001            -    0.000000
# 51314  chr13_108214517_108214517             1018            -    0.000000
# 51315      chr16_1154267_1154267             1161            +    0.000000
#
# [51316 rows x 29 columns]

# %%
#original code sliced first 8 columns (up until the phase column)

# %%
#df.to_csv("/home/ubuntu/honors_research/peak_align/TSS_all_adj+1Nuc.csv", index=False)
# coordinate columns are Unnamed: 3, Unnamed: 10, Unnamed: 19, Unnamed: 25

# %%
df.columns
# Out:
# Index(['TSS', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'CoPRO read2',
#        'Unnamed: 5', 'Distance to closest nuc',
#        'TSS informaion, phase to +1 Nuc', 'NFR', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', '#secondary TSS in 80bp',
#        'Distance to core-promoter', 'Core-promoter', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'PIC occupancy', 'Unnamed: 21',
#        'Adjusted +1 Nucleosome', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Distance to TSS', 'Unnamed: 27', 'phase socre'],
#       dtype='object')

# %%
df1 = df[["TSS", "Unnamed: 1", "Unnamed: 2", "Unnamed: 3", 'Unnamed: 5', 'TSS informaion, phase to +1 Nuc']]
df2 = df[["TSS", "NFR", "Unnamed: 9", "Unnamed: 10", 'Unnamed: 12', 'TSS informaion, phase to +1 Nuc']]
df3 = df[["TSS", "Unnamed: 17", "Unnamed: 18",  "Unnamed: 19",'Unnamed: 21',  'TSS informaion, phase to +1 Nuc']]
df4 = df[["TSS", "Unnamed: 23", "Unnamed: 24", "Unnamed: 25",'Unnamed: 27', 'TSS informaion, phase to +1 Nuc']]

# %%
df3
# Out:
#          TSS  Unnamed: 17  Unnamed: 18                Unnamed: 19 Unnamed: 21  \
# 0       chr1     21782393     21782393   chr1_21782389_21782397_+           +
# 1      chr16     68085691     68085691    chr16_68085691_68085691           +
# 2       chr1    148634356    148634356   chr1_148634356_148634356           -
# 3       chr1    156747338    156747338   chr1_156747338_156747338           +
# 4       chr1    172450016    172450016   chr1_172450016_172450016           -
# ...      ...          ...          ...                        ...         ...
# 51311  chr18     57435381     57435381    chr18_57435381_57435381           +
# 51312  chr19     37251850     37251850    chr19_37251850_37251850           +
# 51313   chr8      1701455      1701455       chr8_1701455_1701455           -
# 51314  chr13    108215562    108215562  chr13_108215562_108215562           -
# 51315  chr16      1153079      1153079      chr16_1153079_1153079           +
#
#                          TSS informaion, phase to +1 Nuc
# 0      -3_AA_-2_-1_TA_0_1_CT_2_c_main_NDR_First_Diver...
# 1      -3_CT_-2_-1_CG_0_1_AC_2_c_main_NDR_First_Diver...
# 2      -3_AT_-2_-1_TA_0_1_CT_2_c_main_NFR_First_Singl...
# 3      -3_AC_-2_-1_CA_0_1_CA_2_c_main_NFR_First_Diver...
# 4      -3_TC_-2_-1_CA_0_1_CT_2_c_main_NFR_First_Refer...
# ...                                                  ...
# 51311  -3_AA_-2_-1_CA_0_1_GA_2_c_main_NFR_First_Refer...
# 51312  -3_CC_-2_-1_CA_0_1_CG_2_c_main_NFR_First_Singl...
# 51313  -3_CG_-2_-1_AG_0_1_GG_2_c_main_NFR_First_Diver...
# 51314  -3_GG_-2_-1_CA_0_1_TC_2_c_main_NDR_First_Diver...
# 51315  -3_CT_-2_-1_CA_0_1_GC_2_c_main_NFR_First_Refer...
#
# [51316 rows x 6 columns]

# %%
df2.to_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_2.bed", sep="\t", index=False, header = False)

# %%
#df1.to_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc.bed", sep="\t", index=False, header = False)
df2.to_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_2.bed", sep="\t", index=False, header = False)
df3.to_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_3.bed", sep="\t", index=False, header = False)
df4.to_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_4.bed", sep="\t", index=False, header = False)

# %% [markdown]
# did some editing in R; converted to CSV to directly delete columns

# %%
df2 = pd.read_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_2.bed", sep=",", header=None)

# %%
df2 = pd.read_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_2.csv", sep=",", header=None)
df3 = pd.read_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_3.csv", sep=",", header=None)
df4 = pd.read_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_4.csv", sep=",", header=None)

# %%
df2.to_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_2.bed", sep="\t", index=False, header = False)
df3.to_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_2.bed", sep="\t", index=False, header = False)
df3.to_csv("/home/ubuntu/honors_research/peak_align/edited_TSS_all_adj+1Nuc_2.bed", sep="\t", index=False, header = False)
