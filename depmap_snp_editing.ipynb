# %%
import pandas as pd

# %%
path = "/home/ubuntu/honors_research/depmap/K562_mutations.csv"
mutations = pd.read_csv(path)

# %%
#display third column
mutations
# Out:
#         Gene Chromosome   Position  Variant Type        Variant Info  \
# 0       CHD5       chr1    6121138  substitution    missense_variant
# 1       CHD5       chr1    6136538           SNV    missense_variant
# 2    TNFRSF9       chr1    7939993           SNV          start_lost
# 3      CASZ1       chr1   10653866           SNV    missense_variant
# 4    PLA2G2E       chr1   19920311           SNV    missense_variant
# ..       ...        ...        ...           ...                 ...
# 293     ZXDA       chrX   57909058           SNV    missense_variant
# 294     ZXDA       chrX   57909607      deletion  frameshift_variant
# 295    MTMR8       chrX   64268590           SNV    missense_variant
# 296    MTMR8       chrX   64336111           SNV    missense_variant
# 297   TEX13C       chrX  125322182           SNV    missense_variant
#
#           Ref Allele Alt Allele  Allele Fraction  Ref Count  Alt Count  ...  \
# 0                 TC         GA            0.426         31         23  ...
# 1                  A          G            0.242         48         15  ...
# 2                  A          G            0.729         13         38  ...
# 3                  G          T            0.488         25         25  ...
# 4                  C          T            0.246         32         11  ...
# ..               ...        ...              ...        ...        ...  ...
# 293                C          A            0.400         11          8  ...
# 294  CCTCGGGGCACAGGT          C            0.417         13         10  ...
# 295                T          C            0.935          0         14  ...
# 296                T          G            0.214         10          2  ...
# 297                G          T            0.250         21          7  ...
#
#     Vep Somatic  LoF Number of Transcripts in Gene Vep Impact  \
# 0           NaN                                NaN   MODERATE
# 1             1                                NaN   MODERATE
# 2           0&1                                1.0       HIGH
# 3             1                                NaN   MODERATE
# 4           NaN                                NaN   MODERATE
# ..          ...                                ...        ...
# 293         NaN                                NaN   MODERATE
# 294         NaN                                1.0       HIGH
# 295         NaN                                NaN   MODERATE
# 296         NaN                                NaN   MODERATE
# 297         NaN                                NaN   MODERATE
#
#     Oncogene High Impact           AM class AM Pathogenicity Hotspot  Intron  \
# 0                  False                NaN              NaN   False     NaN
# 1                  False  likely_pathogenic           0.9967   False     NaN
# 2                  False                NaN              NaN   False     NaN
# 3                  False      likely_benign           0.1163   False     NaN
# 4                  False  likely_pathogenic           0.9222   False     NaN
# ..                   ...                ...              ...     ...     ...
# 293                False          ambiguous           0.4213   False     NaN
# 294                False                NaN              NaN   False     NaN
# 295                False      likely_benign           0.0655   False     NaN
# 296                False      likely_benign           0.3345   False     NaN
# 297                False  likely_pathogenic           0.7715   False     NaN
#
#        Exon  Rescue Reason
# 0     33/42            NaN
# 1     17/42            NaN
# 2     8-Feb            NaN
# 3    21-Nov            NaN
# 4     4-Apr            NaN
# ..      ...            ...
# 293   1-Jan            NaN
# 294   1-Jan            NaN
# 295   14/14            NaN
# 296  14-Oct            NaN
# 297   2-Jan            NaN
#
# [298 rows x 68 columns]

# %%
# filtering for snps (SNV or substiutition)
mutations = mutations[mutations["Variant Type"].isin(["SNV", "substitution"])]
mutations
# Out:
#         Gene Chromosome   Position  Variant Type      Variant Info Ref Allele  \
# 0       CHD5       chr1    6121138  substitution  missense_variant         TC
# 1       CHD5       chr1    6136538           SNV  missense_variant          A
# 2    TNFRSF9       chr1    7939993           SNV        start_lost          A
# 3      CASZ1       chr1   10653866           SNV  missense_variant          G
# 4    PLA2G2E       chr1   19920311           SNV  missense_variant          C
# ..       ...        ...        ...           ...               ...        ...
# 292     TSR2       chrX   54444542           SNV  missense_variant          A
# 293     ZXDA       chrX   57909058           SNV  missense_variant          C
# 295    MTMR8       chrX   64268590           SNV  missense_variant          T
# 296    MTMR8       chrX   64336111           SNV  missense_variant          T
# 297   TEX13C       chrX  125322182           SNV  missense_variant          G
#
#     Alt Allele  Allele Fraction  Ref Count  Alt Count  ... Vep Somatic  \
# 0           GA            0.426         31         23  ...         NaN
# 1            G            0.242         48         15  ...           1
# 2            G            0.729         13         38  ...         0&1
# 3            T            0.488         25         25  ...           1
# 4            T            0.246         32         11  ...         NaN
# ..         ...              ...        ...        ...  ...         ...
# 292          G            0.954          0         19  ...         0&1
# 293          A            0.400         11          8  ...         NaN
# 295          C            0.935          0         14  ...         NaN
# 296          G            0.214         10          2  ...         NaN
# 297          T            0.250         21          7  ...         NaN
#
#      LoF Number of Transcripts in Gene Vep Impact Oncogene High Impact  \
# 0                                  NaN   MODERATE                False
# 1                                  NaN   MODERATE                False
# 2                                  1.0       HIGH                False
# 3                                  NaN   MODERATE                False
# 4                                  NaN   MODERATE                False
# ..                                 ...        ...                  ...
# 292                                NaN   MODERATE                False
# 293                                NaN   MODERATE                False
# 295                                NaN   MODERATE                False
# 296                                NaN   MODERATE                False
# 297                                NaN   MODERATE                False
#
#               AM class AM Pathogenicity Hotspot  Intron    Exon  Rescue Reason
# 0                  NaN              NaN   False     NaN   33/42            NaN
# 1    likely_pathogenic           0.9967   False     NaN   17/42            NaN
# 2                  NaN              NaN   False     NaN   8-Feb            NaN
# 3        likely_benign           0.1163   False     NaN  21-Nov            NaN
# 4    likely_pathogenic           0.9222   False     NaN   4-Apr            NaN
# ..                 ...              ...     ...     ...     ...            ...
# 292  likely_pathogenic           0.8153   False     NaN   5-May            NaN
# 293          ambiguous           0.4213   False     NaN   1-Jan            NaN
# 295      likely_benign           0.0655   False     NaN   14/14            NaN
# 296      likely_benign           0.3345   False     NaN  14-Oct            NaN
# 297  likely_pathogenic           0.7715   False     NaN   2-Jan            NaN
#
# [284 rows x 68 columns]

# %%
# taking chromosome + position columns + making a new column (for end position)
mutations_new = mutations[["Chromosome"]]
mutations_new["start"] = mutations["Position"] - 1
mutations_new["end"] = mutations["Position"]
mutations_new
# Out:
# /tmp/ipykernel_803739/2454380929.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutations_new["start"] = mutations["Position"] - 1
# /tmp/ipykernel_803739/2454380929.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutations_new["end"] = mutations["Position"]
#     Chromosome      start        end
# 0         chr1    6121137    6121138
# 1         chr1    6136537    6136538
# 2         chr1    7939992    7939993
# 3         chr1   10653865   10653866
# 4         chr1   19920310   19920311
# ..         ...        ...        ...
# 292       chrX   54444541   54444542
# 293       chrX   57909057   57909058
# 295       chrX   64268589   64268590
# 296       chrX   64336110   64336111
# 297       chrX  125322181  125322182
#
# [284 rows x 3 columns]

# %%
# export to bed
mutations_new.to_csv("K562_mutations.bed", sep="\t", header=False, index=False)
